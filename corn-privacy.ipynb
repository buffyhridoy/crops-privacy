# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import defaultdict
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import tensorflow_addons as tfa

# %%
from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy
from tensorflow_privacy.privacy.optimizers.dp_optimizer import DPGradientDescentGaussianOptimizer, DPAdamGaussianOptimizer

# %%
train_path = "corn/train"
test_path = "corn/test"
val_path = "corn/val"

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_train = []
Y_train = []

for target in os.listdir(train_path):
    target_path = os.path.join(train_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_train.append(file_path)
        Y_train.append(target)
# Out:
# 100%|██████████| 954/954 [00:00<00:00, 318910.18it/s]
# 100%|██████████| 410/410 [00:00<00:00, 403961.63it/s]
# 100%|██████████| 930/930 [00:00<00:00, 310788.20it/s]
# 100%|██████████| 788/788 [00:00<00:00, 313369.83it/s]

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_test = []
Y_test = []

for target in os.listdir(test_path):
    target_path = os.path.join(test_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_test.append(file_path)
        Y_test.append(target)
# Out:
# 100%|██████████| 119/119 [00:00<00:00, 119407.22it/s]
# 100%|██████████| 52/52 [00:00<00:00, 34477.36it/s]
# 100%|██████████| 116/116 [00:00<00:00, 115021.10it/s]
# 100%|██████████| 99/99 [00:00<?, ?it/s]

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_val = []
Y_val = []

for target in os.listdir(val_path):
    target_path = os.path.join(val_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_val.append(file_path)
        Y_val.append(target)
# Out:
# 100%|██████████| 119/119 [00:00<?, ?it/s]
# 100%|██████████| 51/51 [00:00<?, ?it/s]
# 100%|██████████| 116/116 [00:00<00:00, 116313.47it/s]
# 100%|██████████| 98/98 [00:00<?, ?it/s]

# %%
sns.countplot(x = Y_train)

# %%
sns.countplot(x = Y_val)

# %%
sns.countplot(x = Y_test)

# %%
df_train = pd.DataFrame(list(zip(X_train, Y_train)), columns =['image_path', 'label'])
df_val = pd.DataFrame(list(zip(X_val, Y_val)), columns =['image_path', 'label'])
df_test = pd.DataFrame(list(zip(X_test, Y_test)), columns =['image_path', 'label'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_aug = ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    rescale = 1./255,
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

test_aug = ImageDataGenerator(
    rescale = 1./255,
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

train_generator= train_aug.flow_from_dataframe(
    dataframe=df_train,
    x_col="image_path",
    y_col="label",
    batch_size=16,
    color_mode="rgb",
    target_size = (224, 224),
    class_mode="categorical")

val_generator= test_aug.flow_from_dataframe(
    dataframe=df_val,
    x_col="image_path",
    y_col="label",
    batch_size=16,
    color_mode="rgb",
    target_size = (224, 224),
    class_mode="categorical")

test_generator= test_aug.flow_from_dataframe(
    dataframe=df_test,
    x_col="image_path",
    y_col="label",
    color_mode="rgb",
    batch_size=16,
    shuffle = False, 
    target_size = (224, 224),
    class_mode="categorical")
# Out:
# Found 3082 validated image filenames belonging to 4 classes.
# Found 384 validated image filenames belonging to 4 classes.
# Found 386 validated image filenames belonging to 4 classes.

# %%
"""
This part is to modify the optimizer for the DP library of the tensorflow because it cannot run on the tensorflow 2.0+. 
This is the recognition credit for the notebook:
https://colab.research.google.com/github/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb#scrollTo=hOBQELw7mo9Z&line=21&uniqifier=1
"""
from absl import logging
import collections

from tensorflow_privacy.privacy.dp_query import gaussian_query

def make_optimizer_class(cls):
  """Constructs a DP optimizer class from an existing one."""
  parent_code = tf.compat.v1.train.Optimizer.compute_gradients.__code__
  child_code = cls.compute_gradients.__code__
  GATE_OP = tf.compat.v1.train.Optimizer.GATE_OP  # pylint: disable=invalid-name
  if child_code is not parent_code:
    logging.warning(
        'WARNING: Calling make_optimizer_class() on class %s that overrides '
        'method compute_gradients(). Check to ensure that '
        'make_optimizer_class() does not interfere with overridden version.',
        cls.__name__)

  class DPOptimizerClass(cls):
    """Differentially private subclass of given class cls."""

    _GlobalState = collections.namedtuple(
      '_GlobalState', ['l2_norm_clip', 'stddev'])
    
    def __init__(
        self,
        dp_sum_query,
        num_microbatches=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg, g-doc-args
        **kwargs):
      """Initialize the DPOptimizerClass.

      Args:
        dp_sum_query: DPQuery object, specifying differential privacy
          mechanism to use.
        num_microbatches: How many microbatches into which the minibatch is
          split. If None, will default to the size of the minibatch, and
          per-example gradients will be computed.
        unroll_microbatches: If true, processes microbatches within a Python
          loop instead of a tf.while_loop. Can be used if using a tf.while_loop
          raises an exception.
      """
      super(DPOptimizerClass, self).__init__(*args, **kwargs)
      self._dp_sum_query = dp_sum_query
      self._num_microbatches = num_microbatches
      self._global_state = self._dp_sum_query.initial_global_state()
      # TODO(b/122613513): Set unroll_microbatches=True to avoid this bug.
      # Beware: When num_microbatches is large (>100), enabling this parameter
      # may cause an OOM error.
      self._unroll_microbatches = unroll_microbatches

    def compute_gradients(self,
                          loss,
                          var_list,
                          gate_gradients=GATE_OP,
                          aggregation_method=None,
                          colocate_gradients_with_ops=False,
                          grad_loss=None,
                          gradient_tape=None,
                          curr_noise_mult=0,
                          curr_norm_clip=1):

      self._dp_sum_query = gaussian_query.GaussianSumQuery(curr_norm_clip, 
                                                           curr_norm_clip*curr_noise_mult)
      self._global_state = self._dp_sum_query.make_global_state(curr_norm_clip, 
                                                                curr_norm_clip*curr_noise_mult)
      

      # TF is running in Eager mode, check we received a vanilla tape.
      if not gradient_tape:
        raise ValueError('When in Eager mode, a tape needs to be passed.')

      vector_loss = loss()
      if self._num_microbatches is None:
        self._num_microbatches = tf.shape(input=vector_loss)[0]
      sample_state = self._dp_sum_query.initial_sample_state(var_list)
      microbatches_losses = tf.reshape(vector_loss, [self._num_microbatches, -1])
      sample_params = (self._dp_sum_query.derive_sample_params(self._global_state))

      def process_microbatch(i, sample_state):
        """Process one microbatch (record) with privacy helper."""
        microbatch_loss = tf.reduce_mean(input_tensor=tf.gather(microbatches_losses, [i]))
        grads = gradient_tape.gradient(microbatch_loss, var_list)
        sample_state = self._dp_sum_query.accumulate_record(sample_params, sample_state, grads)
        return sample_state
    
      for idx in range(self._num_microbatches):
        sample_state = process_microbatch(idx, sample_state)

      if curr_noise_mult > 0:
        grad_sums, self._global_state = (self._dp_sum_query.get_noised_result(sample_state, self._global_state))
      else:
        grad_sums = sample_state

      def normalize(v):
        return v / tf.cast(self._num_microbatches, tf.float32)

      final_grads = tf.nest.map_structure(normalize, grad_sums)
      grads_and_vars = final_grads#list(zip(final_grads, var_list))
    
      return grads_and_vars

  return DPOptimizerClass


def make_gaussian_optimizer_class(cls):
  """Constructs a DP optimizer with Gaussian averaging of updates."""

  class DPGaussianOptimizerClass(make_optimizer_class(cls)):
    """DP subclass of given class cls using Gaussian averaging."""

    def __init__(
        self,
        l2_norm_clip,
        noise_multiplier,
        num_microbatches=None,
        ledger=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg
        **kwargs):
      dp_sum_query = gaussian_query.GaussianSumQuery(
          l2_norm_clip, l2_norm_clip * noise_multiplier)

      if ledger:
        dp_sum_query = privacy_ledger.QueryWithLedger(dp_sum_query,
                                                      ledger=ledger)

      super(DPGaussianOptimizerClass, self).__init__(
          dp_sum_query,
          num_microbatches,
          unroll_microbatches,
          *args,
          **kwargs)

    @property
    def ledger(self):
      return self._dp_sum_query.ledger

  return DPGaussianOptimizerClass

# %%
DPSGDGaussianOptimizer_new = make_gaussian_optimizer_class(tf.compat.v1.train.GradientDescentOptimizer)

# %%
l2_norm_clip = 1.5
noise_multiplier = 5
num_microbatches = 250
learning_rate = 0.0009

# %%
def train_model(model, train_generator,val_generator, num_epochs, metrics):
    
    optimizer = DPSGDGaussianOptimizer_new(
    l2_norm_clip=l2_norm_clip,
    noise_multiplier=noise_multiplier,
    num_microbatches=num_microbatches,
    learning_rate=learning_rate)
    
    loss = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, reduction=tf.losses.Reduction.NONE)
    
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=metrics)

    print(model.summary())
    
    history = model.fit(train_generator, epochs=num_epochs, 
                        validation_data=val_generator, verbose=1,
                        #callbacks = [early_stop, rlr]
                        )
    
    return model, history

# %%
import itertools
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, classification_report

metrics = ['accuracy',
                tf.keras.metrics.AUC(),
                tfa.metrics.CohenKappa(num_classes = 4),
                tfa.metrics.F1Score(num_classes = 4),
                tf.keras.metrics.Precision(), 
                tf.keras.metrics.Recall()]

def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    
def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    
# It prints & plots the confusion matrix, normalization can be applied by setting normalize=True.
    
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):

    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_roc_curves(y_true, y_pred, num_classes, class_labels):
    
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

#     # Plot all ROC curves
#     for i in range(num_classes):
        #fig, c_ax = plt.subplots(1,1, figsize = (6, 4))
        plt.plot(fpr[i], tpr[i],
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(class_labels[i], roc_auc[i]))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC curve of class {0}'.format(class_labels[i]))
        plt.legend(loc="lower right")
    plt.show()
    return roc_auc_score(y_test, y_pred)

# %%
def plot_roc_curves(y_true, y_pred, num_classes, class_labels):
    
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

#     # Plot all ROC curves
#     for i in range(num_classes):
        #fig, c_ax = plt.subplots(1,1, figsize = (6, 4))
        plt.plot(fpr[i], tpr[i],
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(class_labels[i], roc_auc[i]))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC curve of class {0}'.format(class_labels[i]))
        plt.legend(loc="lower right")
    plt.show()
    return roc_auc_score(y_test, y_pred)

# %%
def evaluate_model(model, history, test_generator):
    # Evaluate model
    score = model.evaluate(test_generator, verbose=0)
    print('\nTest set accuracy:', score[1], '\n')
    
    y_true = np.array(test_generator.labels)
    y_pred = model.predict(test_generator, verbose = 1)
    y_pred_classes = np.argmax(y_pred,axis = 1)
    class_labels = list(test_generator.class_indices.keys())   
    
    print('\n', sklearn.metrics.classification_report(y_true, y_pred_classes, target_names=class_labels), sep='')
    confusion_mtx = confusion_matrix(y_true, y_pred_classes)
    plot_acc(history)
    plt.show()
    plot_loss(history)
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = class_labels)
    plt.show()
    print("ROC AUC score:", plot_roc_curves(y_true, y_pred, 4, class_labels))

# %%
from keras.layers import Input, Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D, MaxPooling2D,AveragePooling2D, BatchNormalization, PReLU, ReLU, SeparableConv2D
from keras.models import Model, Sequential
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 64
second_filters = 128
third_filters = 256

dropout_conv = 0.3
dropout_dense = 0.3

# create a model with separable convolutional layers
def custom_model():
    inputs = Input((224, 224, 3))
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(inputs)
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(x)
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Flatten()(x)
    x = Dense(4096)(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Dense(4096)(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Dense(4, activation = "softmax")(x)
    model = Model(inputs = inputs, outputs = x)
    model.summary
    return model

# %%
model = custom_model()

# %%
model, history = train_model(model, train_generator, val_generator, 100, metrics)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 218, 218, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 109, 109, 64)     0
#  )
#
#  dropout (Dropout)           (None, 109, 109, 64)      0
#
#  conv2d_3 (Conv2D)           (None, 107, 107, 128)     73856
#
#  conv2d_4 (Conv2D)           (None, 105, 105, 128)     147584
#
#  conv2d_5 (Conv2D)           (None, 103, 103, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 51, 51, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 51, 51, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 49, 49, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 47, 47, 256)       590080
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 256)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 256)       0
#
#  flatten (Flatten)           (None, 123904)            0
#
#  dense (Dense)               (None, 4096)              507514880
#
#  re_lu (ReLU)                (None, 4096)              0
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  re_lu_1 (ReLU)              (None, 4096)              0
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 526,232,580
# Trainable params: 526,232,580
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 193/193 [==============================] - 70s 331ms/step - loss: 1.0980 - accuracy: 0.5036 - auc: 0.7690 - cohen_kappa: 0.2925 - f1_score: 0.3800 - precision: 0.8249 - recall: 0.2109 - val_loss: 0.7742 - val_accuracy: 0.6094 - val_auc: 0.8946 - val_cohen_kappa: 0.4396 - val_f1_score: 0.4208 - val_precision: 0.6626 - val_recall: 0.5677
# Epoch 2/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.8180 - accuracy: 0.6428 - auc: 0.8809 - cohen_kappa: 0.4974 - f1_score: 0.5322 - precision: 0.7933 - recall: 0.4445 - val_loss: 0.6045 - val_accuracy: 0.7917 - val_auc: 0.9373 - val_cohen_kappa: 0.7087 - val_f1_score: 0.6397 - val_precision: 0.8246 - val_recall: 0.7344
# Epoch 3/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.6175 - accuracy: 0.7599 - auc: 0.9351 - cohen_kappa: 0.6656 - f1_score: 0.6526 - precision: 0.8123 - recall: 0.6950 - val_loss: 0.4063 - val_accuracy: 0.8438 - val_auc: 0.9728 - val_cohen_kappa: 0.7812 - val_f1_score: 0.6805 - val_precision: 0.8571 - val_recall: 0.8438
# Epoch 4/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.4701 - accuracy: 0.8134 - auc: 0.9619 - cohen_kappa: 0.7402 - f1_score: 0.6973 - precision: 0.8451 - recall: 0.7738 - val_loss: 0.3958 - val_accuracy: 0.8177 - val_auc: 0.9734 - val_cohen_kappa: 0.7458 - val_f1_score: 0.6718 - val_precision: 0.8298 - val_recall: 0.8125
# Epoch 5/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.3441 - accuracy: 0.8494 - auc: 0.9773 - cohen_kappa: 0.7908 - f1_score: 0.7440 - precision: 0.8612 - recall: 0.8297 - val_loss: 0.2884 - val_accuracy: 0.8646 - val_auc: 0.9852 - val_cohen_kappa: 0.8104 - val_f1_score: 0.7194 - val_precision: 0.8639 - val_recall: 0.8594
# Epoch 6/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.3129 - accuracy: 0.8647 - auc: 0.9813 - cohen_kappa: 0.8126 - f1_score: 0.7825 - precision: 0.8732 - recall: 0.8472 - val_loss: 0.2562 - val_accuracy: 0.8724 - val_auc: 0.9868 - val_cohen_kappa: 0.8244 - val_f1_score: 0.8111 - val_precision: 0.8853 - val_recall: 0.8646
# Epoch 7/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.2972 - accuracy: 0.8754 - auc: 0.9834 - cohen_kappa: 0.8279 - f1_score: 0.8100 - precision: 0.8834 - recall: 0.8679 - val_loss: 1.1603 - val_accuracy: 0.5156 - val_auc: 0.7319 - val_cohen_kappa: 0.3544 - val_f1_score: 0.4589 - val_precision: 1.0000 - val_recall: 0.1927
# Epoch 8/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.5862 - accuracy: 0.7657 - auc: 0.9405 - cohen_kappa: 0.6750 - f1_score: 0.6977 - precision: 0.8294 - recall: 0.6690 - val_loss: 0.2819 - val_accuracy: 0.8646 - val_auc: 0.9853 - val_cohen_kappa: 0.8129 - val_f1_score: 0.8017 - val_precision: 0.8717 - val_recall: 0.8490
# Epoch 9/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.2841 - accuracy: 0.8783 - auc: 0.9848 - cohen_kappa: 0.8324 - f1_score: 0.8222 - precision: 0.8959 - recall: 0.8598 - val_loss: 0.2509 - val_accuracy: 0.8776 - val_auc: 0.9880 - val_cohen_kappa: 0.8320 - val_f1_score: 0.8299 - val_precision: 0.8830 - val_recall: 0.8646
# Epoch 10/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.5841 - accuracy: 0.7901 - auc: 0.9559 - cohen_kappa: 0.7112 - f1_score: 0.7470 - precision: 0.8785 - recall: 0.7294 - val_loss: 1.2843 - val_accuracy: 0.4062 - val_auc: 0.7183 - val_cohen_kappa: 0.1444 - val_f1_score: 0.2549 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.4865 - accuracy: 0.7943 - auc: 0.9578 - cohen_kappa: 0.7142 - f1_score: 0.7126 - precision: 0.8626 - recall: 0.7229 - val_loss: 0.2473 - val_accuracy: 0.8828 - val_auc: 0.9872 - val_cohen_kappa: 0.8389 - val_f1_score: 0.8252 - val_precision: 0.8915 - val_recall: 0.8776
# Epoch 12/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.2673 - accuracy: 0.8832 - auc: 0.9862 - cohen_kappa: 0.8388 - f1_score: 0.8209 - precision: 0.8930 - recall: 0.8722 - val_loss: 0.2216 - val_accuracy: 0.8750 - val_auc: 0.9898 - val_cohen_kappa: 0.8302 - val_f1_score: 0.8351 - val_precision: 0.8773 - val_recall: 0.8750
# Epoch 13/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.3605 - accuracy: 0.8563 - auc: 0.9781 - cohen_kappa: 0.8024 - f1_score: 0.8131 - precision: 0.8932 - recall: 0.8196 - val_loss: 0.5416 - val_accuracy: 0.7943 - val_auc: 0.9489 - val_cohen_kappa: 0.7247 - val_f1_score: 0.7467 - val_precision: 0.8159 - val_recall: 0.7734
# Epoch 14/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.4039 - accuracy: 0.8423 - auc: 0.9709 - cohen_kappa: 0.7827 - f1_score: 0.8021 - precision: 0.8689 - recall: 0.8086 - val_loss: 0.3946 - val_accuracy: 0.8464 - val_auc: 0.9721 - val_cohen_kappa: 0.7905 - val_f1_score: 0.8215 - val_precision: 0.8864 - val_recall: 0.8125
# Epoch 15/100
# 193/193 [==============================] - 50s 256ms/step - loss: 0.2471 - accuracy: 0.8955 - auc: 0.9886 - cohen_kappa: 0.8563 - f1_score: 0.8556 - precision: 0.9066 - recall: 0.8819 - val_loss: 0.3010 - val_accuracy: 0.8646 - val_auc: 0.9832 - val_cohen_kappa: 0.8134 - val_f1_score: 0.8247 - val_precision: 0.8901 - val_recall: 0.8438
# Epoch 16/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.2232 - accuracy: 0.9130 - auc: 0.9904 - cohen_kappa: 0.8806 - f1_score: 0.8784 - precision: 0.9198 - recall: 0.9004 - val_loss: 0.2123 - val_accuracy: 0.9062 - val_auc: 0.9906 - val_cohen_kappa: 0.8724 - val_f1_score: 0.8746 - val_precision: 0.9132 - val_recall: 0.9036
# Epoch 17/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1927 - accuracy: 0.9208 - auc: 0.9926 - cohen_kappa: 0.8915 - f1_score: 0.8900 - precision: 0.9273 - recall: 0.9143 - val_loss: 0.2087 - val_accuracy: 0.9323 - val_auc: 0.9911 - val_cohen_kappa: 0.9069 - val_f1_score: 0.8994 - val_precision: 0.9367 - val_recall: 0.9245
# Epoch 18/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1973 - accuracy: 0.9189 - auc: 0.9922 - cohen_kappa: 0.8888 - f1_score: 0.8889 - precision: 0.9286 - recall: 0.9117 - val_loss: 0.2607 - val_accuracy: 0.8854 - val_auc: 0.9872 - val_cohen_kappa: 0.8450 - val_f1_score: 0.8516 - val_precision: 0.8868 - val_recall: 0.8776
# Epoch 19/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.7140 - accuracy: 0.8021 - auc: 0.9505 - cohen_kappa: 0.7262 - f1_score: 0.7655 - precision: 0.8943 - recall: 0.7025 - val_loss: 0.2614 - val_accuracy: 0.9089 - val_auc: 0.9877 - val_cohen_kappa: 0.8747 - val_f1_score: 0.8747 - val_precision: 0.9241 - val_recall: 0.8880
# Epoch 20/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.2422 - accuracy: 0.8981 - auc: 0.9890 - cohen_kappa: 0.8600 - f1_score: 0.8580 - precision: 0.9102 - recall: 0.8812 - val_loss: 0.2810 - val_accuracy: 0.8854 - val_auc: 0.9839 - val_cohen_kappa: 0.8444 - val_f1_score: 0.8524 - val_precision: 0.9046 - val_recall: 0.8646
# Epoch 21/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.3642 - accuracy: 0.8621 - auc: 0.9771 - cohen_kappa: 0.8103 - f1_score: 0.8299 - precision: 0.8944 - recall: 0.8160 - val_loss: 0.3955 - val_accuracy: 0.8646 - val_auc: 0.9720 - val_cohen_kappa: 0.8160 - val_f1_score: 0.8344 - val_precision: 0.8774 - val_recall: 0.8385
# Epoch 22/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.4256 - accuracy: 0.8410 - auc: 0.9724 - cohen_kappa: 0.7800 - f1_score: 0.7712 - precision: 0.8685 - recall: 0.8125 - val_loss: 0.1980 - val_accuracy: 0.9219 - val_auc: 0.9930 - val_cohen_kappa: 0.8921 - val_f1_score: 0.8810 - val_precision: 0.9239 - val_recall: 0.9167
# Epoch 23/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.1989 - accuracy: 0.9234 - auc: 0.9929 - cohen_kappa: 0.8950 - f1_score: 0.8924 - precision: 0.9304 - recall: 0.9150 - val_loss: 0.1759 - val_accuracy: 0.9193 - val_auc: 0.9935 - val_cohen_kappa: 0.8891 - val_f1_score: 0.8819 - val_precision: 0.9241 - val_recall: 0.9193
# Epoch 24/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1881 - accuracy: 0.9263 - auc: 0.9927 - cohen_kappa: 0.8990 - f1_score: 0.8973 - precision: 0.9326 - recall: 0.9205 - val_loss: 0.1689 - val_accuracy: 0.9349 - val_auc: 0.9939 - val_cohen_kappa: 0.9111 - val_f1_score: 0.9115 - val_precision: 0.9370 - val_recall: 0.9297
# Epoch 25/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1617 - accuracy: 0.9315 - auc: 0.9948 - cohen_kappa: 0.9061 - f1_score: 0.9039 - precision: 0.9392 - recall: 0.9270 - val_loss: 0.2047 - val_accuracy: 0.9193 - val_auc: 0.9923 - val_cohen_kappa: 0.8900 - val_f1_score: 0.8924 - val_precision: 0.9239 - val_recall: 0.9167
# Epoch 26/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1616 - accuracy: 0.9419 - auc: 0.9942 - cohen_kappa: 0.9204 - f1_score: 0.9183 - precision: 0.9429 - recall: 0.9384 - val_loss: 0.1705 - val_accuracy: 0.9349 - val_auc: 0.9939 - val_cohen_kappa: 0.9111 - val_f1_score: 0.9101 - val_precision: 0.9349 - val_recall: 0.9349
# Epoch 27/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.1569 - accuracy: 0.9384 - auc: 0.9946 - cohen_kappa: 0.9156 - f1_score: 0.9142 - precision: 0.9413 - recall: 0.9322 - val_loss: 0.1897 - val_accuracy: 0.9193 - val_auc: 0.9927 - val_cohen_kappa: 0.8900 - val_f1_score: 0.8924 - val_precision: 0.9241 - val_recall: 0.9193
# Epoch 28/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1594 - accuracy: 0.9338 - auc: 0.9946 - cohen_kappa: 0.9094 - f1_score: 0.9090 - precision: 0.9419 - recall: 0.9306 - val_loss: 0.1795 - val_accuracy: 0.9245 - val_auc: 0.9930 - val_cohen_kappa: 0.8973 - val_f1_score: 0.8992 - val_precision: 0.9267 - val_recall: 0.9219
# Epoch 29/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1742 - accuracy: 0.9332 - auc: 0.9936 - cohen_kappa: 0.9085 - f1_score: 0.9106 - precision: 0.9394 - recall: 0.9302 - val_loss: 0.1850 - val_accuracy: 0.9323 - val_auc: 0.9930 - val_cohen_kappa: 0.9069 - val_f1_score: 0.9005 - val_precision: 0.9393 - val_recall: 0.9271
# Epoch 30/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1466 - accuracy: 0.9400 - auc: 0.9954 - cohen_kappa: 0.9177 - f1_score: 0.9161 - precision: 0.9440 - recall: 0.9345 - val_loss: 0.1671 - val_accuracy: 0.9401 - val_auc: 0.9947 - val_cohen_kappa: 0.9182 - val_f1_score: 0.9173 - val_precision: 0.9426 - val_recall: 0.9401
# Epoch 31/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.1256 - accuracy: 0.9533 - auc: 0.9964 - cohen_kappa: 0.9360 - f1_score: 0.9344 - precision: 0.9538 - recall: 0.9513 - val_loss: 0.1879 - val_accuracy: 0.9375 - val_auc: 0.9940 - val_cohen_kappa: 0.9141 - val_f1_score: 0.9102 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 32/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1343 - accuracy: 0.9487 - auc: 0.9960 - cohen_kappa: 0.9298 - f1_score: 0.9281 - precision: 0.9502 - recall: 0.9481 - val_loss: 0.1724 - val_accuracy: 0.9349 - val_auc: 0.9944 - val_cohen_kappa: 0.9108 - val_f1_score: 0.9087 - val_precision: 0.9373 - val_recall: 0.9349
# Epoch 33/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1300 - accuracy: 0.9504 - auc: 0.9960 - cohen_kappa: 0.9320 - f1_score: 0.9308 - precision: 0.9515 - recall: 0.9484 - val_loss: 0.1669 - val_accuracy: 0.9453 - val_auc: 0.9944 - val_cohen_kappa: 0.9249 - val_f1_score: 0.9220 - val_precision: 0.9476 - val_recall: 0.9427
# Epoch 34/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1209 - accuracy: 0.9565 - auc: 0.9967 - cohen_kappa: 0.9405 - f1_score: 0.9394 - precision: 0.9580 - recall: 0.9543 - val_loss: 0.1445 - val_accuracy: 0.9427 - val_auc: 0.9953 - val_cohen_kappa: 0.9215 - val_f1_score: 0.9185 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 35/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.1200 - accuracy: 0.9546 - auc: 0.9966 - cohen_kappa: 0.9378 - f1_score: 0.9367 - precision: 0.9573 - recall: 0.9520 - val_loss: 0.1889 - val_accuracy: 0.9323 - val_auc: 0.9929 - val_cohen_kappa: 0.9073 - val_f1_score: 0.9061 - val_precision: 0.9344 - val_recall: 0.9271
# Epoch 36/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1202 - accuracy: 0.9536 - auc: 0.9969 - cohen_kappa: 0.9364 - f1_score: 0.9357 - precision: 0.9550 - recall: 0.9504 - val_loss: 0.1925 - val_accuracy: 0.9349 - val_auc: 0.9933 - val_cohen_kappa: 0.9113 - val_f1_score: 0.9123 - val_precision: 0.9373 - val_recall: 0.9349
# Epoch 37/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1229 - accuracy: 0.9539 - auc: 0.9966 - cohen_kappa: 0.9369 - f1_score: 0.9354 - precision: 0.9551 - recall: 0.9526 - val_loss: 0.1556 - val_accuracy: 0.9375 - val_auc: 0.9949 - val_cohen_kappa: 0.9149 - val_f1_score: 0.9160 - val_precision: 0.9373 - val_recall: 0.9349
# Epoch 38/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.1425 - accuracy: 0.9478 - auc: 0.9956 - cohen_kappa: 0.9285 - f1_score: 0.9288 - precision: 0.9514 - recall: 0.9403 - val_loss: 0.1489 - val_accuracy: 0.9453 - val_auc: 0.9941 - val_cohen_kappa: 0.9252 - val_f1_score: 0.9241 - val_precision: 0.9453 - val_recall: 0.9453
# Epoch 39/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1026 - accuracy: 0.9604 - auc: 0.9976 - cohen_kappa: 0.9458 - f1_score: 0.9441 - precision: 0.9613 - recall: 0.9598 - val_loss: 0.1486 - val_accuracy: 0.9427 - val_auc: 0.9958 - val_cohen_kappa: 0.9218 - val_f1_score: 0.9213 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 40/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.2379 - accuracy: 0.9335 - auc: 0.9896 - cohen_kappa: 0.9089 - f1_score: 0.9161 - precision: 0.9402 - recall: 0.9189 - val_loss: 0.1473 - val_accuracy: 0.9505 - val_auc: 0.9954 - val_cohen_kappa: 0.9323 - val_f1_score: 0.9316 - val_precision: 0.9530 - val_recall: 0.9505
# Epoch 41/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.1205 - accuracy: 0.9572 - auc: 0.9966 - cohen_kappa: 0.9413 - f1_score: 0.9398 - precision: 0.9593 - recall: 0.9555 - val_loss: 0.1769 - val_accuracy: 0.9375 - val_auc: 0.9946 - val_cohen_kappa: 0.9139 - val_f1_score: 0.9072 - val_precision: 0.9424 - val_recall: 0.9375
# Epoch 42/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.1133 - accuracy: 0.9581 - auc: 0.9966 - cohen_kappa: 0.9427 - f1_score: 0.9410 - precision: 0.9603 - recall: 0.9572 - val_loss: 0.1566 - val_accuracy: 0.9479 - val_auc: 0.9951 - val_cohen_kappa: 0.9289 - val_f1_score: 0.9299 - val_precision: 0.9478 - val_recall: 0.9453
# Epoch 43/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.1100 - accuracy: 0.9578 - auc: 0.9970 - cohen_kappa: 0.9422 - f1_score: 0.9409 - precision: 0.9590 - recall: 0.9562 - val_loss: 0.2674 - val_accuracy: 0.8906 - val_auc: 0.9878 - val_cohen_kappa: 0.8523 - val_f1_score: 0.8598 - val_precision: 0.8953 - val_recall: 0.8906
# Epoch 44/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.1141 - accuracy: 0.9559 - auc: 0.9969 - cohen_kappa: 0.9396 - f1_score: 0.9386 - precision: 0.9571 - recall: 0.9555 - val_loss: 0.1635 - val_accuracy: 0.9479 - val_auc: 0.9937 - val_cohen_kappa: 0.9284 - val_f1_score: 0.9246 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 45/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.1051 - accuracy: 0.9607 - auc: 0.9976 - cohen_kappa: 0.9462 - f1_score: 0.9451 - precision: 0.9610 - recall: 0.9594 - val_loss: 0.1521 - val_accuracy: 0.9427 - val_auc: 0.9952 - val_cohen_kappa: 0.9219 - val_f1_score: 0.9237 - val_precision: 0.9427 - val_recall: 0.9427
# Epoch 46/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.1015 - accuracy: 0.9604 - auc: 0.9975 - cohen_kappa: 0.9458 - f1_score: 0.9443 - precision: 0.9610 - recall: 0.9601 - val_loss: 0.2103 - val_accuracy: 0.9271 - val_auc: 0.9911 - val_cohen_kappa: 0.9009 - val_f1_score: 0.9047 - val_precision: 0.9269 - val_recall: 0.9245
# Epoch 47/100
# 193/193 [==============================] - 48s 251ms/step - loss: 0.0997 - accuracy: 0.9653 - auc: 0.9974 - cohen_kappa: 0.9525 - f1_score: 0.9521 - precision: 0.9659 - recall: 0.9643 - val_loss: 0.1551 - val_accuracy: 0.9479 - val_auc: 0.9939 - val_cohen_kappa: 0.9283 - val_f1_score: 0.9217 - val_precision: 0.9478 - val_recall: 0.9453
# Epoch 48/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.1022 - accuracy: 0.9630 - auc: 0.9974 - cohen_kappa: 0.9493 - f1_score: 0.9483 - precision: 0.9636 - recall: 0.9617 - val_loss: 0.1526 - val_accuracy: 0.9427 - val_auc: 0.9951 - val_cohen_kappa: 0.9219 - val_f1_score: 0.9234 - val_precision: 0.9427 - val_recall: 0.9427
# Epoch 49/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.0895 - accuracy: 0.9666 - auc: 0.9981 - cohen_kappa: 0.9542 - f1_score: 0.9527 - precision: 0.9672 - recall: 0.9659 - val_loss: 0.1791 - val_accuracy: 0.9427 - val_auc: 0.9936 - val_cohen_kappa: 0.9218 - val_f1_score: 0.9229 - val_precision: 0.9426 - val_recall: 0.9401
# Epoch 50/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.0774 - accuracy: 0.9744 - auc: 0.9981 - cohen_kappa: 0.9649 - f1_score: 0.9640 - precision: 0.9750 - recall: 0.9740 - val_loss: 0.1597 - val_accuracy: 0.9583 - val_auc: 0.9933 - val_cohen_kappa: 0.9430 - val_f1_score: 0.9419 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 51/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.0936 - accuracy: 0.9624 - auc: 0.9973 - cohen_kappa: 0.9484 - f1_score: 0.9471 - precision: 0.9630 - recall: 0.9614 - val_loss: 0.1632 - val_accuracy: 0.9375 - val_auc: 0.9943 - val_cohen_kappa: 0.9142 - val_f1_score: 0.9101 - val_precision: 0.9398 - val_recall: 0.9349
# Epoch 52/100
# 193/193 [==============================] - 48s 249ms/step - loss: 0.0823 - accuracy: 0.9698 - auc: 0.9983 - cohen_kappa: 0.9587 - f1_score: 0.9583 - precision: 0.9698 - recall: 0.9692 - val_loss: 0.1602 - val_accuracy: 0.9427 - val_auc: 0.9945 - val_cohen_kappa: 0.9218 - val_f1_score: 0.9220 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 53/100
# 193/193 [==============================] - 49s 255ms/step - loss: 0.0838 - accuracy: 0.9692 - auc: 0.9983 - cohen_kappa: 0.9578 - f1_score: 0.9566 - precision: 0.9695 - recall: 0.9689 - val_loss: 0.1374 - val_accuracy: 0.9505 - val_auc: 0.9962 - val_cohen_kappa: 0.9323 - val_f1_score: 0.9322 - val_precision: 0.9504 - val_recall: 0.9479
# Epoch 54/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.0893 - accuracy: 0.9685 - auc: 0.9978 - cohen_kappa: 0.9569 - f1_score: 0.9561 - precision: 0.9691 - recall: 0.9659 - val_loss: 0.1458 - val_accuracy: 0.9453 - val_auc: 0.9961 - val_cohen_kappa: 0.9255 - val_f1_score: 0.9256 - val_precision: 0.9453 - val_recall: 0.9453
# Epoch 55/100
# 193/193 [==============================] - 48s 248ms/step - loss: 0.0788 - accuracy: 0.9701 - auc: 0.9984 - cohen_kappa: 0.9591 - f1_score: 0.9575 - precision: 0.9711 - recall: 0.9692 - val_loss: 0.1404 - val_accuracy: 0.9531 - val_auc: 0.9962 - val_cohen_kappa: 0.9359 - val_f1_score: 0.9361 - val_precision: 0.9531 - val_recall: 0.9531
# Epoch 56/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.0873 - accuracy: 0.9695 - auc: 0.9972 - cohen_kappa: 0.9582 - f1_score: 0.9574 - precision: 0.9701 - recall: 0.9682 - val_loss: 0.1701 - val_accuracy: 0.9505 - val_auc: 0.9950 - val_cohen_kappa: 0.9326 - val_f1_score: 0.9344 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 57/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.0785 - accuracy: 0.9727 - auc: 0.9979 - cohen_kappa: 0.9627 - f1_score: 0.9620 - precision: 0.9734 - recall: 0.9721 - val_loss: 0.1586 - val_accuracy: 0.9557 - val_auc: 0.9939 - val_cohen_kappa: 0.9396 - val_f1_score: 0.9403 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 58/100
# 193/193 [==============================] - 48s 249ms/step - loss: 0.0681 - accuracy: 0.9747 - auc: 0.9985 - cohen_kappa: 0.9653 - f1_score: 0.9639 - precision: 0.9750 - recall: 0.9747 - val_loss: 0.1486 - val_accuracy: 0.9505 - val_auc: 0.9962 - val_cohen_kappa: 0.9323 - val_f1_score: 0.9320 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 59/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.0850 - accuracy: 0.9679 - auc: 0.9978 - cohen_kappa: 0.9560 - f1_score: 0.9557 - precision: 0.9688 - recall: 0.9663 - val_loss: 0.1732 - val_accuracy: 0.9349 - val_auc: 0.9925 - val_cohen_kappa: 0.9103 - val_f1_score: 0.9002 - val_precision: 0.9373 - val_recall: 0.9349
# Epoch 60/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.0674 - accuracy: 0.9744 - auc: 0.9985 - cohen_kappa: 0.9649 - f1_score: 0.9636 - precision: 0.9747 - recall: 0.9737 - val_loss: 0.1239 - val_accuracy: 0.9661 - val_auc: 0.9952 - val_cohen_kappa: 0.9537 - val_f1_score: 0.9527 - val_precision: 0.9687 - val_recall: 0.9661
# Epoch 61/100
# 193/193 [==============================] - 50s 257ms/step - loss: 0.0774 - accuracy: 0.9698 - auc: 0.9985 - cohen_kappa: 0.9587 - f1_score: 0.9576 - precision: 0.9698 - recall: 0.9692 - val_loss: 0.1228 - val_accuracy: 0.9531 - val_auc: 0.9967 - val_cohen_kappa: 0.9358 - val_f1_score: 0.9340 - val_precision: 0.9530 - val_recall: 0.9505
# Epoch 62/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.0751 - accuracy: 0.9757 - auc: 0.9980 - cohen_kappa: 0.9667 - f1_score: 0.9662 - precision: 0.9760 - recall: 0.9753 - val_loss: 0.1380 - val_accuracy: 0.9479 - val_auc: 0.9959 - val_cohen_kappa: 0.9288 - val_f1_score: 0.9289 - val_precision: 0.9504 - val_recall: 0.9479
# Epoch 63/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0744 - accuracy: 0.9731 - auc: 0.9984 - cohen_kappa: 0.9631 - f1_score: 0.9624 - precision: 0.9730 - recall: 0.9721 - val_loss: 0.1479 - val_accuracy: 0.9505 - val_auc: 0.9961 - val_cohen_kappa: 0.9319 - val_f1_score: 0.9261 - val_precision: 0.9530 - val_recall: 0.9505
# Epoch 64/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0618 - accuracy: 0.9799 - auc: 0.9987 - cohen_kappa: 0.9724 - f1_score: 0.9716 - precision: 0.9802 - recall: 0.9799 - val_loss: 0.1523 - val_accuracy: 0.9479 - val_auc: 0.9958 - val_cohen_kappa: 0.9289 - val_f1_score: 0.9297 - val_precision: 0.9504 - val_recall: 0.9479
# Epoch 65/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0642 - accuracy: 0.9796 - auc: 0.9988 - cohen_kappa: 0.9720 - f1_score: 0.9715 - precision: 0.9796 - recall: 0.9792 - val_loss: 0.1611 - val_accuracy: 0.9401 - val_auc: 0.9956 - val_cohen_kappa: 0.9183 - val_f1_score: 0.9194 - val_precision: 0.9401 - val_recall: 0.9401
# Epoch 66/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.0632 - accuracy: 0.9757 - auc: 0.9989 - cohen_kappa: 0.9667 - f1_score: 0.9657 - precision: 0.9760 - recall: 0.9757 - val_loss: 0.1610 - val_accuracy: 0.9505 - val_auc: 0.9944 - val_cohen_kappa: 0.9324 - val_f1_score: 0.9325 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 67/100
# 193/193 [==============================] - 48s 251ms/step - loss: 0.0736 - accuracy: 0.9760 - auc: 0.9986 - cohen_kappa: 0.9671 - f1_score: 0.9660 - precision: 0.9763 - recall: 0.9753 - val_loss: 0.1282 - val_accuracy: 0.9583 - val_auc: 0.9967 - val_cohen_kappa: 0.9431 - val_f1_score: 0.9423 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 68/100
# 193/193 [==============================] - 49s 253ms/step - loss: 0.0738 - accuracy: 0.9753 - auc: 0.9983 - cohen_kappa: 0.9662 - f1_score: 0.9652 - precision: 0.9763 - recall: 0.9750 - val_loss: 0.2287 - val_accuracy: 0.9219 - val_auc: 0.9881 - val_cohen_kappa: 0.8943 - val_f1_score: 0.8985 - val_precision: 0.9217 - val_recall: 0.9193
# Epoch 69/100
# 193/193 [==============================] - 48s 249ms/step - loss: 0.0670 - accuracy: 0.9783 - auc: 0.9986 - cohen_kappa: 0.9702 - f1_score: 0.9698 - precision: 0.9786 - recall: 0.9776 - val_loss: 0.1545 - val_accuracy: 0.9427 - val_auc: 0.9960 - val_cohen_kappa: 0.9217 - val_f1_score: 0.9221 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 70/100
# 193/193 [==============================] - 49s 251ms/step - loss: 0.0560 - accuracy: 0.9792 - auc: 0.9988 - cohen_kappa: 0.9715 - f1_score: 0.9706 - precision: 0.9805 - recall: 0.9789 - val_loss: 0.1426 - val_accuracy: 0.9479 - val_auc: 0.9961 - val_cohen_kappa: 0.9287 - val_f1_score: 0.9277 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 71/100
# 193/193 [==============================] - 48s 250ms/step - loss: 0.0722 - accuracy: 0.9734 - auc: 0.9984 - cohen_kappa: 0.9636 - f1_score: 0.9633 - precision: 0.9746 - recall: 0.9718 - val_loss: 0.1356 - val_accuracy: 0.9557 - val_auc: 0.9962 - val_cohen_kappa: 0.9394 - val_f1_score: 0.9391 - val_precision: 0.9605 - val_recall: 0.9505
# Epoch 72/100
# 193/193 [==============================] - 48s 250ms/step - loss: 0.0873 - accuracy: 0.9718 - auc: 0.9975 - cohen_kappa: 0.9613 - f1_score: 0.9626 - precision: 0.9721 - recall: 0.9705 - val_loss: 0.1696 - val_accuracy: 0.9531 - val_auc: 0.9941 - val_cohen_kappa: 0.9358 - val_f1_score: 0.9340 - val_precision: 0.9529 - val_recall: 0.9479
# Epoch 73/100
# 193/193 [==============================] - 49s 252ms/step - loss: 0.0688 - accuracy: 0.9760 - auc: 0.9985 - cohen_kappa: 0.9671 - f1_score: 0.9663 - precision: 0.9769 - recall: 0.9757 - val_loss: 0.1591 - val_accuracy: 0.9479 - val_auc: 0.9958 - val_cohen_kappa: 0.9289 - val_f1_score: 0.9293 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 74/100
# 193/193 [==============================] - 49s 254ms/step - loss: 0.0674 - accuracy: 0.9776 - auc: 0.9982 - cohen_kappa: 0.9693 - f1_score: 0.9688 - precision: 0.9776 - recall: 0.9773 - val_loss: 0.1613 - val_accuracy: 0.9401 - val_auc: 0.9959 - val_cohen_kappa: 0.9179 - val_f1_score: 0.9161 - val_precision: 0.9401 - val_recall: 0.9401
# Epoch 75/100
# 193/193 [==============================] - 50s 260ms/step - loss: 0.0541 - accuracy: 0.9799 - auc: 0.9987 - cohen_kappa: 0.9725 - f1_score: 0.9716 - precision: 0.9805 - recall: 0.9799 - val_loss: 0.1608 - val_accuracy: 0.9531 - val_auc: 0.9962 - val_cohen_kappa: 0.9359 - val_f1_score: 0.9356 - val_precision: 0.9556 - val_recall: 0.9531
# Epoch 76/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0755 - accuracy: 0.9779 - auc: 0.9979 - cohen_kappa: 0.9698 - f1_score: 0.9705 - precision: 0.9785 - recall: 0.9753 - val_loss: 0.1520 - val_accuracy: 0.9557 - val_auc: 0.9958 - val_cohen_kappa: 0.9397 - val_f1_score: 0.9411 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 77/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0591 - accuracy: 0.9802 - auc: 0.9989 - cohen_kappa: 0.9729 - f1_score: 0.9723 - precision: 0.9808 - recall: 0.9802 - val_loss: 0.1198 - val_accuracy: 0.9531 - val_auc: 0.9968 - val_cohen_kappa: 0.9358 - val_f1_score: 0.9342 - val_precision: 0.9531 - val_recall: 0.9531
# Epoch 78/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0557 - accuracy: 0.9802 - auc: 0.9988 - cohen_kappa: 0.9729 - f1_score: 0.9720 - precision: 0.9802 - recall: 0.9799 - val_loss: 0.1202 - val_accuracy: 0.9609 - val_auc: 0.9969 - val_cohen_kappa: 0.9466 - val_f1_score: 0.9463 - val_precision: 0.9634 - val_recall: 0.9609
# Epoch 79/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0549 - accuracy: 0.9835 - auc: 0.9987 - cohen_kappa: 0.9773 - f1_score: 0.9767 - precision: 0.9834 - recall: 0.9831 - val_loss: 0.1343 - val_accuracy: 0.9583 - val_auc: 0.9966 - val_cohen_kappa: 0.9429 - val_f1_score: 0.9408 - val_precision: 0.9582 - val_recall: 0.9557
# Epoch 80/100
# 193/193 [==============================] - 50s 258ms/step - loss: 0.0677 - accuracy: 0.9796 - auc: 0.9986 - cohen_kappa: 0.9720 - f1_score: 0.9719 - precision: 0.9805 - recall: 0.9792 - val_loss: 0.1210 - val_accuracy: 0.9557 - val_auc: 0.9967 - val_cohen_kappa: 0.9396 - val_f1_score: 0.9407 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 81/100
# 193/193 [==============================] - 50s 259ms/step - loss: 0.0543 - accuracy: 0.9825 - auc: 0.9989 - cohen_kappa: 0.9760 - f1_score: 0.9751 - precision: 0.9828 - recall: 0.9815 - val_loss: 0.1280 - val_accuracy: 0.9557 - val_auc: 0.9952 - val_cohen_kappa: 0.9395 - val_f1_score: 0.9399 - val_precision: 0.9582 - val_recall: 0.9557
# Epoch 82/100
# 193/193 [==============================] - 50s 256ms/step - loss: 0.0462 - accuracy: 0.9844 - auc: 0.9992 - cohen_kappa: 0.9787 - f1_score: 0.9782 - precision: 0.9844 - recall: 0.9844 - val_loss: 0.1461 - val_accuracy: 0.9635 - val_auc: 0.9938 - val_cohen_kappa: 0.9501 - val_f1_score: 0.9501 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 83/100
# 193/193 [==============================] - 50s 257ms/step - loss: 0.1787 - accuracy: 0.9500 - auc: 0.9930 - cohen_kappa: 0.9315 - f1_score: 0.9375 - precision: 0.9625 - recall: 0.9422 - val_loss: 0.3285 - val_accuracy: 0.8464 - val_auc: 0.9805 - val_cohen_kappa: 0.7893 - val_f1_score: 0.7865 - val_precision: 0.8839 - val_recall: 0.8125
# Epoch 84/100
# 193/193 [==============================] - 50s 257ms/step - loss: 0.0981 - accuracy: 0.9643 - auc: 0.9977 - cohen_kappa: 0.9511 - f1_score: 0.9510 - precision: 0.9661 - recall: 0.9620 - val_loss: 0.1348 - val_accuracy: 0.9531 - val_auc: 0.9962 - val_cohen_kappa: 0.9359 - val_f1_score: 0.9339 - val_precision: 0.9554 - val_recall: 0.9479
# Epoch 85/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0567 - accuracy: 0.9812 - auc: 0.9990 - cohen_kappa: 0.9742 - f1_score: 0.9733 - precision: 0.9818 - recall: 0.9809 - val_loss: 0.1756 - val_accuracy: 0.9375 - val_auc: 0.9950 - val_cohen_kappa: 0.9147 - val_f1_score: 0.9158 - val_precision: 0.9396 - val_recall: 0.9323
# Epoch 86/100
# 193/193 [==============================] - 51s 265ms/step - loss: 0.0564 - accuracy: 0.9789 - auc: 0.9992 - cohen_kappa: 0.9711 - f1_score: 0.9703 - precision: 0.9795 - recall: 0.9789 - val_loss: 0.2029 - val_accuracy: 0.9375 - val_auc: 0.9910 - val_cohen_kappa: 0.9141 - val_f1_score: 0.9090 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 87/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0636 - accuracy: 0.9773 - auc: 0.9985 - cohen_kappa: 0.9689 - f1_score: 0.9682 - precision: 0.9795 - recall: 0.9770 - val_loss: 0.1449 - val_accuracy: 0.9401 - val_auc: 0.9960 - val_cohen_kappa: 0.9179 - val_f1_score: 0.9151 - val_precision: 0.9401 - val_recall: 0.9401
# Epoch 88/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0541 - accuracy: 0.9799 - auc: 0.9989 - cohen_kappa: 0.9724 - f1_score: 0.9716 - precision: 0.9802 - recall: 0.9796 - val_loss: 0.1745 - val_accuracy: 0.9427 - val_auc: 0.9928 - val_cohen_kappa: 0.9219 - val_f1_score: 0.9218 - val_precision: 0.9427 - val_recall: 0.9427
# Epoch 89/100
# 193/193 [==============================] - 51s 265ms/step - loss: 0.0789 - accuracy: 0.9757 - auc: 0.9982 - cohen_kappa: 0.9667 - f1_score: 0.9672 - precision: 0.9766 - recall: 0.9747 - val_loss: 0.1239 - val_accuracy: 0.9609 - val_auc: 0.9967 - val_cohen_kappa: 0.9465 - val_f1_score: 0.9443 - val_precision: 0.9609 - val_recall: 0.9609
# Epoch 90/100
# 193/193 [==============================] - 50s 259ms/step - loss: 0.0645 - accuracy: 0.9779 - auc: 0.9984 - cohen_kappa: 0.9698 - f1_score: 0.9694 - precision: 0.9792 - recall: 0.9779 - val_loss: 0.1319 - val_accuracy: 0.9479 - val_auc: 0.9960 - val_cohen_kappa: 0.9289 - val_f1_score: 0.9286 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 91/100
# 193/193 [==============================] - 50s 260ms/step - loss: 0.0567 - accuracy: 0.9805 - auc: 0.9986 - cohen_kappa: 0.9733 - f1_score: 0.9729 - precision: 0.9805 - recall: 0.9796 - val_loss: 0.1163 - val_accuracy: 0.9557 - val_auc: 0.9969 - val_cohen_kappa: 0.9394 - val_f1_score: 0.9373 - val_precision: 0.9556 - val_recall: 0.9531
# Epoch 92/100
# 193/193 [==============================] - 52s 267ms/step - loss: 0.0507 - accuracy: 0.9831 - auc: 0.9991 - cohen_kappa: 0.9769 - f1_score: 0.9766 - precision: 0.9841 - recall: 0.9822 - val_loss: 0.1520 - val_accuracy: 0.9505 - val_auc: 0.9949 - val_cohen_kappa: 0.9320 - val_f1_score: 0.9269 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 93/100
# 193/193 [==============================] - 52s 266ms/step - loss: 0.0428 - accuracy: 0.9848 - auc: 0.9994 - cohen_kappa: 0.9791 - f1_score: 0.9786 - precision: 0.9854 - recall: 0.9844 - val_loss: 0.1611 - val_accuracy: 0.9505 - val_auc: 0.9946 - val_cohen_kappa: 0.9323 - val_f1_score: 0.9316 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 94/100
# 193/193 [==============================] - 52s 267ms/step - loss: 0.0422 - accuracy: 0.9844 - auc: 0.9992 - cohen_kappa: 0.9787 - f1_score: 0.9780 - precision: 0.9847 - recall: 0.9844 - val_loss: 0.1450 - val_accuracy: 0.9427 - val_auc: 0.9951 - val_cohen_kappa: 0.9213 - val_f1_score: 0.9148 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 95/100
# 193/193 [==============================] - 52s 267ms/step - loss: 0.0317 - accuracy: 0.9899 - auc: 0.9996 - cohen_kappa: 0.9862 - f1_score: 0.9858 - precision: 0.9899 - recall: 0.9899 - val_loss: 0.1993 - val_accuracy: 0.9505 - val_auc: 0.9907 - val_cohen_kappa: 0.9325 - val_f1_score: 0.9322 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 96/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0439 - accuracy: 0.9831 - auc: 0.9990 - cohen_kappa: 0.9769 - f1_score: 0.9767 - precision: 0.9834 - recall: 0.9831 - val_loss: 0.2404 - val_accuracy: 0.9297 - val_auc: 0.9871 - val_cohen_kappa: 0.9031 - val_f1_score: 0.8944 - val_precision: 0.9297 - val_recall: 0.9297
# Epoch 97/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0619 - accuracy: 0.9805 - auc: 0.9980 - cohen_kappa: 0.9733 - f1_score: 0.9731 - precision: 0.9805 - recall: 0.9805 - val_loss: 0.1289 - val_accuracy: 0.9557 - val_auc: 0.9965 - val_cohen_kappa: 0.9394 - val_f1_score: 0.9390 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 98/100
# 193/193 [==============================] - 51s 264ms/step - loss: 0.0448 - accuracy: 0.9864 - auc: 0.9992 - cohen_kappa: 0.9813 - f1_score: 0.9806 - precision: 0.9864 - recall: 0.9860 - val_loss: 0.1489 - val_accuracy: 0.9505 - val_auc: 0.9962 - val_cohen_kappa: 0.9322 - val_f1_score: 0.9310 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 99/100
# 193/193 [==============================] - 51s 263ms/step - loss: 0.0460 - accuracy: 0.9857 - auc: 0.9986 - cohen_kappa: 0.9805 - f1_score: 0.9800 - precision: 0.9860 - recall: 0.9854 - val_loss: 0.2136 - val_accuracy: 0.9271 - val_auc: 0.9903 - val_cohen_kappa: 0.9011 - val_f1_score: 0.9049 - val_precision: 0.9269 - val_recall: 0.9245
# Epoch 100/100
# 193/193 [==============================] - 51s 263ms/step - loss: 0.0446 - accuracy: 0.9844 - auc: 0.9989 - cohen_kappa: 0.9787 - f1_score: 0.9783 - precision: 0.9847 - recall: 0.9844 - val_loss: 0.1250 - val_accuracy: 0.9479 - val_auc: 0.9965 - val_cohen_kappa: 0.9287 - val_f1_score: 0.9274 - val_precision: 0.9479 - val_recall: 0.9479

# %%
evaluate_model(model, history, test_generator)
# Out:
# Test set accuracy: 0.9533678889274597
#
# 25/25 [==============================] - 2s 75ms/step
#
#                              precision    recall  f1-score   support
#
#          Corn___Common_Rust       1.00      1.00      1.00       119
#       Corn___Gray_Leaf_Spot       0.77      0.92      0.84        52
#              Corn___Healthy       1.00      1.00      1.00       116
# Corn___Northern_Leaf_Blight       0.96      0.86      0.90        99
#
#                    accuracy                           0.95       386
#                   macro avg       0.93      0.95      0.94       386
#                weighted avg       0.96      0.95      0.95       386
# ROC AUC score: 0.9944776553145181

# %%
import pandas as pd

# %%
from tensorflow.keras.utils import load_img, img_to_array
image_path= df_test['image_path'][152]
img = load_img(image_path, target_size=(224,224,3)) # stores image in PIL format
image_array=img_to_array(img)

# %%
from PIL import Image
display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x2961AC52C08>

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions

    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.layers[-2].output])

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Make model
model = model
last_conv_layer_name ="conv2d_8"
# Remove last layer's softmax
model.layers[-1].activation = None

img_array=np.expand_dims(image_array, axis=0)
# Prepare particular image 

# Generate class activation heatmap
heatmap= make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
import matplotlib.cm as cm
def save_and_display_gradcam(img_path, heatmap, cam_path, alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image.open(cam_path))

# %%
save_and_display_gradcam(image_path, heatmap,cam_path="Gradcam/GradCamCorn.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x2945A8DE608>
