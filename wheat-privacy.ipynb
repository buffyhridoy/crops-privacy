# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import defaultdict
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import tensorflow_addons as tfa

# %%
from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy
from tensorflow_privacy.privacy.optimizers.dp_optimizer import DPGradientDescentGaussianOptimizer, DPAdamGaussianOptimizer

# %%
train_path = "wheat/train"
test_path = "wheat/test"
val_path = "wheat/val"

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_train = []
Y_train = []

for target in os.listdir(train_path):
    target_path = os.path.join(train_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_train.append(file_path)
        Y_train.append(target)
# Out:
# 100%|██████████| 722/722 [00:00<00:00, 292786.18it/s]
# 100%|██████████| 893/893 [00:00<00:00, 297145.06it/s]
# 100%|██████████| 739/739 [00:00<00:00, 369923.70it/s]

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_test = []
Y_test = []

for target in os.listdir(test_path):
    target_path = os.path.join(test_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_test.append(file_path)
        Y_test.append(target)
# Out:
# 100%|██████████| 90/90 [00:00<?, ?it/s]
# 100%|██████████| 111/111 [00:00<00:00, 71046.50it/s]
# 100%|██████████| 92/92 [00:00<?, ?it/s]

# %%
from tqdm import tqdm
from PIL import Image
from collections import defaultdict

X_val = []
Y_val = []

for target in os.listdir(val_path):
    target_path = os.path.join(val_path, target)
    for file in tqdm(os.listdir(target_path)):
        file_path = os.path.join(target_path, file)
        X_val.append(file_path)
        Y_val.append(target)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 90027.99it/s]
# 100%|██████████| 112/112 [00:00<?, ?it/s]
# 100%|██████████| 93/93 [00:00<00:00, 93318.25it/s]

# %%
sns.countplot(x = Y_train)

# %%
sns.countplot(x = Y_val)

# %%
sns.countplot(x = Y_test)

# %%
df_train = pd.DataFrame(list(zip(X_train, Y_train)), columns =['image_path', 'label'])
df_val = pd.DataFrame(list(zip(X_val, Y_val)), columns =['image_path', 'label'])
df_test = pd.DataFrame(list(zip(X_test, Y_test)), columns =['image_path', 'label'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_aug = ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    rescale = 1./255,
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

test_aug = ImageDataGenerator(
    rescale = 1./255,
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

train_generator= train_aug.flow_from_dataframe(
    dataframe=df_train,
    x_col="image_path",
    y_col="label",
    batch_size=16,
    color_mode="rgb",
    target_size = (224, 224),
    class_mode="categorical")

val_generator= test_aug.flow_from_dataframe(
    dataframe=df_val,
    x_col="image_path",
    y_col="label",
    batch_size=16,
    color_mode="rgb",
    target_size = (224, 224),
    class_mode="categorical")

test_generator= test_aug.flow_from_dataframe(
    dataframe=df_test,
    x_col="image_path",
    y_col="label",
    color_mode="rgb",
    batch_size=16,
    shuffle = False, 
    target_size = (224, 224),
    class_mode="categorical")
# Out:
# Found 2354 validated image filenames belonging to 3 classes.
# Found 295 validated image filenames belonging to 3 classes.
# Found 293 validated image filenames belonging to 3 classes.

# %%
"""
This part is to modify the optimizer for the DP library of the tensorflow because it cannot run on the tensorflow 2.0+. 
This is the recognition credit for the notebook:
https://colab.research.google.com/github/ricardocarvalhods/dpcgan/blob/master/DP_CGAN_MNIST.ipynb#scrollTo=hOBQELw7mo9Z&line=21&uniqifier=1
"""
from absl import logging
import collections

from tensorflow_privacy.privacy.dp_query import gaussian_query

def make_optimizer_class(cls):
  """Constructs a DP optimizer class from an existing one."""
  parent_code = tf.compat.v1.train.Optimizer.compute_gradients.__code__
  child_code = cls.compute_gradients.__code__
  GATE_OP = tf.compat.v1.train.Optimizer.GATE_OP  # pylint: disable=invalid-name
  if child_code is not parent_code:
    logging.warning(
        'WARNING: Calling make_optimizer_class() on class %s that overrides '
        'method compute_gradients(). Check to ensure that '
        'make_optimizer_class() does not interfere with overridden version.',
        cls.__name__)

  class DPOptimizerClass(cls):
    """Differentially private subclass of given class cls."""

    _GlobalState = collections.namedtuple(
      '_GlobalState', ['l2_norm_clip', 'stddev'])
    
    def __init__(
        self,
        dp_sum_query,
        num_microbatches=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg, g-doc-args
        **kwargs):
      """Initialize the DPOptimizerClass.

      Args:
        dp_sum_query: DPQuery object, specifying differential privacy
          mechanism to use.
        num_microbatches: How many microbatches into which the minibatch is
          split. If None, will default to the size of the minibatch, and
          per-example gradients will be computed.
        unroll_microbatches: If true, processes microbatches within a Python
          loop instead of a tf.while_loop. Can be used if using a tf.while_loop
          raises an exception.
      """
      super(DPOptimizerClass, self).__init__(*args, **kwargs)
      self._dp_sum_query = dp_sum_query
      self._num_microbatches = num_microbatches
      self._global_state = self._dp_sum_query.initial_global_state()
      # TODO(b/122613513): Set unroll_microbatches=True to avoid this bug.
      # Beware: When num_microbatches is large (>100), enabling this parameter
      # may cause an OOM error.
      self._unroll_microbatches = unroll_microbatches

    def compute_gradients(self,
                          loss,
                          var_list,
                          gate_gradients=GATE_OP,
                          aggregation_method=None,
                          colocate_gradients_with_ops=False,
                          grad_loss=None,
                          gradient_tape=None,
                          curr_noise_mult=0,
                          curr_norm_clip=1):

      self._dp_sum_query = gaussian_query.GaussianSumQuery(curr_norm_clip, 
                                                           curr_norm_clip*curr_noise_mult)
      self._global_state = self._dp_sum_query.make_global_state(curr_norm_clip, 
                                                                curr_norm_clip*curr_noise_mult)
      

      # TF is running in Eager mode, check we received a vanilla tape.
      if not gradient_tape:
        raise ValueError('When in Eager mode, a tape needs to be passed.')

      vector_loss = loss()
      if self._num_microbatches is None:
        self._num_microbatches = tf.shape(input=vector_loss)[0]
      sample_state = self._dp_sum_query.initial_sample_state(var_list)
      microbatches_losses = tf.reshape(vector_loss, [self._num_microbatches, -1])
      sample_params = (self._dp_sum_query.derive_sample_params(self._global_state))

      def process_microbatch(i, sample_state):
        """Process one microbatch (record) with privacy helper."""
        microbatch_loss = tf.reduce_mean(input_tensor=tf.gather(microbatches_losses, [i]))
        grads = gradient_tape.gradient(microbatch_loss, var_list)
        sample_state = self._dp_sum_query.accumulate_record(sample_params, sample_state, grads)
        return sample_state
    
      for idx in range(self._num_microbatches):
        sample_state = process_microbatch(idx, sample_state)

      if curr_noise_mult > 0:
        grad_sums, self._global_state = (self._dp_sum_query.get_noised_result(sample_state, self._global_state))
      else:
        grad_sums = sample_state

      def normalize(v):
        return v / tf.cast(self._num_microbatches, tf.float32)

      final_grads = tf.nest.map_structure(normalize, grad_sums)
      grads_and_vars = final_grads#list(zip(final_grads, var_list))
    
      return grads_and_vars

  return DPOptimizerClass


def make_gaussian_optimizer_class(cls):
  """Constructs a DP optimizer with Gaussian averaging of updates."""

  class DPGaussianOptimizerClass(make_optimizer_class(cls)):
    """DP subclass of given class cls using Gaussian averaging."""

    def __init__(
        self,
        l2_norm_clip,
        noise_multiplier,
        num_microbatches=None,
        ledger=None,
        unroll_microbatches=False,
        *args,  # pylint: disable=keyword-arg-before-vararg
        **kwargs):
      dp_sum_query = gaussian_query.GaussianSumQuery(
          l2_norm_clip, l2_norm_clip * noise_multiplier)

      if ledger:
        dp_sum_query = privacy_ledger.QueryWithLedger(dp_sum_query,
                                                      ledger=ledger)

      super(DPGaussianOptimizerClass, self).__init__(
          dp_sum_query,
          num_microbatches,
          unroll_microbatches,
          *args,
          **kwargs)

    @property
    def ledger(self):
      return self._dp_sum_query.ledger

  return DPGaussianOptimizerClass

# %%
DPSGDGaussianOptimizer_new = make_gaussian_optimizer_class(tf.compat.v1.train.GradientDescentOptimizer)

# %%
l2_norm_clip = 1.5
noise_multiplier = 5
num_microbatches = 250
learning_rate = 0.0009

# %%
def train_model(model, train_generator,val_generator, num_epochs, metrics):
    
    optimizer = DPSGDGaussianOptimizer_new(
    l2_norm_clip=l2_norm_clip,
    noise_multiplier=noise_multiplier,
    num_microbatches=num_microbatches,
    learning_rate=learning_rate)
    
    loss = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, reduction=tf.losses.Reduction.NONE)
    
    model.compile(loss=loss, 
                  optimizer=optimizer, 
                  metrics=metrics)

    print(model.summary())
    
    history = model.fit(train_generator, epochs=num_epochs, 
                        validation_data=val_generator, verbose=1,
                        #callbacks = [early_stop, rlr]
                        )
    
    return model, history

# %%
import itertools
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, classification_report

metrics = ['accuracy',
                tf.keras.metrics.AUC(),
                tfa.metrics.CohenKappa(num_classes = 3),
                tfa.metrics.F1Score(num_classes = 3),
                tf.keras.metrics.Precision(), 
                tf.keras.metrics.Recall()]

def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    
def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    
# It prints & plots the confusion matrix, normalization can be applied by setting normalize=True.
    
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):

    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_roc_curves(y_true, y_pred, num_classes, class_labels):
    
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

#     # Plot all ROC curves
#     for i in range(num_classes):
        #fig, c_ax = plt.subplots(1,1, figsize = (6, 4))
        plt.plot(fpr[i], tpr[i],
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(class_labels[i], roc_auc[i]))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC curve of class {0}'.format(class_labels[i]))
        plt.legend(loc="lower right")
    plt.show()
    return roc_auc_score(y_test, y_pred)

# %%
def plot_roc_curves(y_true, y_pred, num_classes, class_labels):
    
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_test = lb.transform(y_true)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

#     # Plot all ROC curves
#     for i in range(num_classes):
        #fig, c_ax = plt.subplots(1,1, figsize = (6, 4))
        plt.plot(fpr[i], tpr[i],
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(class_labels[i], roc_auc[i]))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC curve of class {0}'.format(class_labels[i]))
        plt.legend(loc="lower right")
    plt.show()
    return roc_auc_score(y_test, y_pred)

# %%
def evaluate_model(model, history, test_generator):
    # Evaluate model
    score = model.evaluate(test_generator, verbose=0)
    print('\nTest set accuracy:', score[1], '\n')
    
    y_true = np.array(test_generator.labels)
    y_pred = model.predict(test_generator, verbose = 1)
    y_pred_classes = np.argmax(y_pred,axis = 1)
    class_labels = list(test_generator.class_indices.keys())   
    
    print('\n', sklearn.metrics.classification_report(y_true, y_pred_classes, target_names=class_labels), sep='')
    confusion_mtx = confusion_matrix(y_true, y_pred_classes)
    plot_acc(history)
    plt.show()
    plot_loss(history)
    plt.show()
    plot_confusion_matrix(confusion_mtx, classes = class_labels)
    plt.show()
    print("ROC AUC score:", plot_roc_curves(y_true, y_pred, 3, class_labels))

# %%
from keras.layers import Input, Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D, MaxPooling2D,AveragePooling2D, BatchNormalization, PReLU, ReLU, SeparableConv2D
from keras.models import Model, Sequential
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 64
second_filters = 128
third_filters = 256

dropout_conv = 0.3
dropout_dense = 0.3

# create a model with separable convolutional layers
def custom_model():
    inputs = Input((224, 224, 3))
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(inputs)
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(x)
    x = Conv2D(first_filters, kernel_size, activation = 'relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(second_filters, kernel_size, activation ='relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = Conv2D(third_filters, kernel_size, activation ='relu')(x)
    x = MaxPooling2D(pool_size = pool_size)(x)
    x = Dropout(dropout_conv)(x)
    x = Flatten()(x)
    x = Dense(4096)(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Dense(4096)(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Dense(3, activation = "softmax")(x)
    model = Model(inputs = inputs, outputs = x)
    model.summary
    return model

# %%
model = custom_model()

# %%
model, history = train_model(model, train_generator, val_generator, 50, metrics)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 218, 218, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 109, 109, 64)     0
#  )
#
#  dropout (Dropout)           (None, 109, 109, 64)      0
#
#  conv2d_3 (Conv2D)           (None, 107, 107, 128)     73856
#
#  conv2d_4 (Conv2D)           (None, 105, 105, 128)     147584
#
#  conv2d_5 (Conv2D)           (None, 103, 103, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 51, 51, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 51, 51, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 49, 49, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 47, 47, 256)       590080
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 256)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 256)       0
#
#  flatten (Flatten)           (None, 123904)            0
#
#  dense (Dense)               (None, 4096)              507514880
#
#  re_lu (ReLU)                (None, 4096)              0
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  re_lu_1 (ReLU)              (None, 4096)              0
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 526,228,483
# Trainable params: 526,228,483
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 148/148 [==============================] - 81s 506ms/step - loss: 1.0287 - accuracy: 0.4359 - auc: 0.6377 - cohen_kappa: 0.1074 - f1_score: 0.3231 - precision: 0.7090 - recall: 0.1066 - val_loss: 1.0160 - val_accuracy: 0.4881 - val_auc: 0.7273 - val_cohen_kappa: 0.1872 - val_f1_score: 0.3772 - val_precision: 0.5161 - val_recall: 0.3797
# Epoch 2/50
# 148/148 [==============================] - 42s 281ms/step - loss: 1.0632 - accuracy: 0.3815 - auc: 0.5674 - cohen_kappa: 0.0876 - f1_score: 0.3099 - precision: 0.6979 - recall: 0.0697 - val_loss: 1.0963 - val_accuracy: 0.3797 - val_auc: 0.5322 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 148/148 [==============================] - 42s 285ms/step - loss: 1.0941 - accuracy: 0.3764 - auc: 0.5412 - cohen_kappa: 0.0013 - f1_score: 0.2119 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0949 - val_accuracy: 0.3797 - val_auc: 0.5684 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 148/148 [==============================] - 41s 277ms/step - loss: 1.0926 - accuracy: 0.3794 - auc: 0.5451 - cohen_kappa: 0.0000e+00 - f1_score: 0.1833 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0875 - val_accuracy: 0.3797 - val_auc: 0.6855 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 148/148 [==============================] - 42s 282ms/step - loss: 1.0522 - accuracy: 0.3895 - auc: 0.5836 - cohen_kappa: 0.0657 - f1_score: 0.3063 - precision: 0.7333 - recall: 0.0841 - val_loss: 1.0989 - val_accuracy: 0.3051 - val_auc: 0.5136 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1558 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 148/148 [==============================] - 42s 280ms/step - loss: 1.0957 - accuracy: 0.3781 - auc: 0.5275 - cohen_kappa: 0.0010 - f1_score: 0.1992 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0938 - val_accuracy: 0.3797 - val_auc: 0.5373 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 148/148 [==============================] - 42s 282ms/step - loss: 1.0942 - accuracy: 0.3794 - auc: 0.5361 - cohen_kappa: 0.0000e+00 - f1_score: 0.1833 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0923 - val_accuracy: 0.3797 - val_auc: 0.5855 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 148/148 [==============================] - 43s 285ms/step - loss: 0.9446 - accuracy: 0.5000 - auc: 0.7083 - cohen_kappa: 0.2178 - f1_score: 0.3834 - precision: 0.8462 - recall: 0.1822 - val_loss: 0.7331 - val_accuracy: 0.6542 - val_auc: 0.8830 - val_cohen_kappa: 0.4826 - val_f1_score: 0.5540 - val_precision: 0.9882 - val_recall: 0.2847
# Epoch 9/50
# 148/148 [==============================] - 41s 279ms/step - loss: 0.9594 - accuracy: 0.4567 - auc: 0.6774 - cohen_kappa: 0.1937 - f1_score: 0.4539 - precision: 0.9083 - recall: 0.1389 - val_loss: 1.0948 - val_accuracy: 0.3797 - val_auc: 0.5373 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 148/148 [==============================] - 43s 285ms/step - loss: 1.0968 - accuracy: 0.3730 - auc: 0.5309 - cohen_kappa: -0.0072 - f1_score: 0.1938 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0945 - val_accuracy: 0.3797 - val_auc: 0.5681 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 148/148 [==============================] - 42s 280ms/step - loss: 1.0952 - accuracy: 0.3768 - auc: 0.5326 - cohen_kappa: -0.0023 - f1_score: 0.1903 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0935 - val_accuracy: 0.3797 - val_auc: 0.5653 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1835 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 148/148 [==============================] - 43s 289ms/step - loss: 1.0823 - accuracy: 0.3955 - auc: 0.5591 - cohen_kappa: 0.0356 - f1_score: 0.2543 - precision: 0.6032 - recall: 0.0323 - val_loss: 1.1109 - val_accuracy: 0.3051 - val_auc: 0.4656 - val_cohen_kappa: 0.0000e+00 - val_f1_score: 0.1558 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 148/148 [==============================] - 42s 284ms/step - loss: 0.9988 - accuracy: 0.4622 - auc: 0.6651 - cohen_kappa: 0.1943 - f1_score: 0.4116 - precision: 0.7589 - recall: 0.1444 - val_loss: 0.7040 - val_accuracy: 0.7322 - val_auc: 0.8772 - val_cohen_kappa: 0.5913 - val_f1_score: 0.6713 - val_precision: 0.8462 - val_recall: 0.3729
# Epoch 14/50
# 148/148 [==============================] - 42s 286ms/step - loss: 0.6791 - accuracy: 0.6924 - auc: 0.8720 - cohen_kappa: 0.5359 - f1_score: 0.6593 - precision: 0.8284 - recall: 0.4019 - val_loss: 0.6353 - val_accuracy: 0.6305 - val_auc: 0.8724 - val_cohen_kappa: 0.4497 - val_f1_score: 0.5633 - val_precision: 0.6559 - val_recall: 0.6203
# Epoch 15/50
# 148/148 [==============================] - 43s 290ms/step - loss: 0.6295 - accuracy: 0.6882 - auc: 0.8789 - cohen_kappa: 0.5315 - f1_score: 0.6723 - precision: 0.7342 - recall: 0.5879 - val_loss: 0.5634 - val_accuracy: 0.7390 - val_auc: 0.9198 - val_cohen_kappa: 0.6061 - val_f1_score: 0.6932 - val_precision: 0.7736 - val_recall: 0.6949
# Epoch 16/50
# 148/148 [==============================] - 43s 286ms/step - loss: 0.5926 - accuracy: 0.7094 - auc: 0.8931 - cohen_kappa: 0.5626 - f1_score: 0.6942 - precision: 0.7414 - recall: 0.6381 - val_loss: 0.5168 - val_accuracy: 0.7153 - val_auc: 0.9157 - val_cohen_kappa: 0.5731 - val_f1_score: 0.6720 - val_precision: 0.7305 - val_recall: 0.6983
# Epoch 17/50
# 148/148 [==============================] - 43s 287ms/step - loss: 0.5709 - accuracy: 0.7315 - auc: 0.9027 - cohen_kappa: 0.5958 - f1_score: 0.7182 - precision: 0.7499 - recall: 0.6827 - val_loss: 0.6770 - val_accuracy: 0.6542 - val_auc: 0.8801 - val_cohen_kappa: 0.4843 - val_f1_score: 0.5977 - val_precision: 0.6538 - val_recall: 0.6339
# Epoch 18/50
# 148/148 [==============================] - 41s 276ms/step - loss: 0.5255 - accuracy: 0.7523 - auc: 0.9198 - cohen_kappa: 0.6267 - f1_score: 0.7410 - precision: 0.7671 - recall: 0.7332 - val_loss: 0.6507 - val_accuracy: 0.7051 - val_auc: 0.8802 - val_cohen_kappa: 0.5593 - val_f1_score: 0.7029 - val_precision: 0.7034 - val_recall: 0.6915
# Epoch 19/50
# 148/148 [==============================] - 41s 276ms/step - loss: 0.5073 - accuracy: 0.7727 - auc: 0.9270 - cohen_kappa: 0.6577 - f1_score: 0.7640 - precision: 0.7880 - recall: 0.7549 - val_loss: 0.5186 - val_accuracy: 0.7559 - val_auc: 0.9190 - val_cohen_kappa: 0.6336 - val_f1_score: 0.7330 - val_precision: 0.7703 - val_recall: 0.7390
# Epoch 20/50
# 148/148 [==============================] - 42s 282ms/step - loss: 0.4684 - accuracy: 0.8020 - auc: 0.9386 - cohen_kappa: 0.7018 - f1_score: 0.7942 - precision: 0.8161 - recall: 0.7859 - val_loss: 0.7842 - val_accuracy: 0.6644 - val_auc: 0.8878 - val_cohen_kappa: 0.4982 - val_f1_score: 0.5835 - val_precision: 0.6797 - val_recall: 0.6475
# Epoch 21/50
# 148/148 [==============================] - 42s 283ms/step - loss: 0.4163 - accuracy: 0.8360 - auc: 0.9527 - cohen_kappa: 0.7531 - f1_score: 0.8300 - precision: 0.8477 - recall: 0.8161 - val_loss: 0.2893 - val_accuracy: 0.8881 - val_auc: 0.9788 - val_cohen_kappa: 0.8314 - val_f1_score: 0.8844 - val_precision: 0.8881 - val_recall: 0.8881
# Epoch 22/50
# 148/148 [==============================] - 42s 284ms/step - loss: 0.7730 - accuracy: 0.7052 - auc: 0.8696 - cohen_kappa: 0.5555 - f1_score: 0.6972 - precision: 0.8741 - recall: 0.4809 - val_loss: 0.4516 - val_accuracy: 0.8000 - val_auc: 0.9473 - val_cohen_kappa: 0.6991 - val_f1_score: 0.7783 - val_precision: 0.8296 - val_recall: 0.7593
# Epoch 23/50
# 148/148 [==============================] - 42s 282ms/step - loss: 0.4585 - accuracy: 0.8127 - auc: 0.9421 - cohen_kappa: 0.7182 - f1_score: 0.8060 - precision: 0.8292 - recall: 0.7901 - val_loss: 0.2772 - val_accuracy: 0.9051 - val_auc: 0.9790 - val_cohen_kappa: 0.8569 - val_f1_score: 0.9023 - val_precision: 0.9100 - val_recall: 0.8915
# Epoch 24/50
# 148/148 [==============================] - 42s 284ms/step - loss: 0.3989 - accuracy: 0.8619 - auc: 0.9570 - cohen_kappa: 0.7922 - f1_score: 0.8585 - precision: 0.8737 - recall: 0.8437 - val_loss: 0.3365 - val_accuracy: 0.8780 - val_auc: 0.9696 - val_cohen_kappa: 0.8169 - val_f1_score: 0.8752 - val_precision: 0.8819 - val_recall: 0.8610
# Epoch 25/50
# 148/148 [==============================] - 42s 284ms/step - loss: 0.2689 - accuracy: 0.9091 - auc: 0.9785 - cohen_kappa: 0.8632 - f1_score: 0.9071 - precision: 0.9158 - recall: 0.9057 - val_loss: 0.2378 - val_accuracy: 0.9051 - val_auc: 0.9847 - val_cohen_kappa: 0.8574 - val_f1_score: 0.9035 - val_precision: 0.9075 - val_recall: 0.8983
# Epoch 26/50
# 148/148 [==============================] - 41s 278ms/step - loss: 0.2544 - accuracy: 0.9155 - auc: 0.9814 - cohen_kappa: 0.8728 - f1_score: 0.9137 - precision: 0.9193 - recall: 0.9095 - val_loss: 0.3333 - val_accuracy: 0.8814 - val_auc: 0.9727 - val_cohen_kappa: 0.8217 - val_f1_score: 0.8755 - val_precision: 0.8862 - val_recall: 0.8712
# Epoch 27/50
# 148/148 [==============================] - 44s 294ms/step - loss: 0.2182 - accuracy: 0.9223 - auc: 0.9862 - cohen_kappa: 0.8830 - f1_score: 0.9208 - precision: 0.9264 - recall: 0.9201 - val_loss: 0.5169 - val_accuracy: 0.8881 - val_auc: 0.9612 - val_cohen_kappa: 0.8303 - val_f1_score: 0.8837 - val_precision: 0.8904 - val_recall: 0.8814
# Epoch 28/50
# 148/148 [==============================] - 42s 284ms/step - loss: 0.2376 - accuracy: 0.9214 - auc: 0.9833 - cohen_kappa: 0.8817 - f1_score: 0.9205 - precision: 0.9281 - recall: 0.9155 - val_loss: 0.2165 - val_accuracy: 0.9119 - val_auc: 0.9895 - val_cohen_kappa: 0.8672 - val_f1_score: 0.9112 - val_precision: 0.9181 - val_recall: 0.9119
# Epoch 29/50
# 148/148 [==============================] - 42s 282ms/step - loss: 0.1921 - accuracy: 0.9303 - auc: 0.9892 - cohen_kappa: 0.8951 - f1_score: 0.9291 - precision: 0.9332 - recall: 0.9257 - val_loss: 0.2156 - val_accuracy: 0.9119 - val_auc: 0.9883 - val_cohen_kappa: 0.8671 - val_f1_score: 0.9098 - val_precision: 0.9116 - val_recall: 0.9085
# Epoch 30/50
# 148/148 [==============================] - 42s 283ms/step - loss: 0.1837 - accuracy: 0.9359 - auc: 0.9895 - cohen_kappa: 0.9034 - f1_score: 0.9343 - precision: 0.9389 - recall: 0.9333 - val_loss: 0.3329 - val_accuracy: 0.8949 - val_auc: 0.9718 - val_cohen_kappa: 0.8427 - val_f1_score: 0.8954 - val_precision: 0.9041 - val_recall: 0.8949
# Epoch 31/50
# 148/148 [==============================] - 42s 285ms/step - loss: 0.1728 - accuracy: 0.9435 - auc: 0.9908 - cohen_kappa: 0.9149 - f1_score: 0.9423 - precision: 0.9473 - recall: 0.9401 - val_loss: 0.2753 - val_accuracy: 0.9017 - val_auc: 0.9833 - val_cohen_kappa: 0.8521 - val_f1_score: 0.8969 - val_precision: 0.9014 - val_recall: 0.8983
# Epoch 32/50
# 148/148 [==============================] - 42s 285ms/step - loss: 0.1728 - accuracy: 0.9384 - auc: 0.9900 - cohen_kappa: 0.9072 - f1_score: 0.9372 - precision: 0.9410 - recall: 0.9350 - val_loss: 0.2675 - val_accuracy: 0.9017 - val_auc: 0.9830 - val_cohen_kappa: 0.8522 - val_f1_score: 0.8988 - val_precision: 0.9075 - val_recall: 0.8983
# Epoch 33/50
# 148/148 [==============================] - 40s 271ms/step - loss: 0.1580 - accuracy: 0.9444 - auc: 0.9923 - cohen_kappa: 0.9162 - f1_score: 0.9434 - precision: 0.9478 - recall: 0.9414 - val_loss: 0.3132 - val_accuracy: 0.8915 - val_auc: 0.9748 - val_cohen_kappa: 0.8369 - val_f1_score: 0.8866 - val_precision: 0.8915 - val_recall: 0.8915
# Epoch 34/50
# 148/148 [==============================] - 40s 272ms/step - loss: 0.1536 - accuracy: 0.9486 - auc: 0.9927 - cohen_kappa: 0.9226 - f1_score: 0.9474 - precision: 0.9516 - recall: 0.9444 - val_loss: 0.4447 - val_accuracy: 0.8475 - val_auc: 0.9570 - val_cohen_kappa: 0.7718 - val_f1_score: 0.8440 - val_precision: 0.8464 - val_recall: 0.8407
# Epoch 35/50
# 148/148 [==============================] - 41s 276ms/step - loss: 0.1626 - accuracy: 0.9460 - auc: 0.9912 - cohen_kappa: 0.9187 - f1_score: 0.9443 - precision: 0.9508 - recall: 0.9435 - val_loss: 0.2509 - val_accuracy: 0.9051 - val_auc: 0.9820 - val_cohen_kappa: 0.8568 - val_f1_score: 0.9016 - val_precision: 0.9135 - val_recall: 0.8949
# Epoch 36/50
# 148/148 [==============================] - 41s 276ms/step - loss: 0.1388 - accuracy: 0.9541 - auc: 0.9935 - cohen_kappa: 0.9309 - f1_score: 0.9527 - precision: 0.9561 - recall: 0.9520 - val_loss: 0.2477 - val_accuracy: 0.9153 - val_auc: 0.9848 - val_cohen_kappa: 0.8723 - val_f1_score: 0.9125 - val_precision: 0.9175 - val_recall: 0.9051
# Epoch 37/50
# 148/148 [==============================] - 41s 274ms/step - loss: 0.1248 - accuracy: 0.9571 - auc: 0.9945 - cohen_kappa: 0.9354 - f1_score: 0.9560 - precision: 0.9582 - recall: 0.9550 - val_loss: 0.2886 - val_accuracy: 0.8847 - val_auc: 0.9793 - val_cohen_kappa: 0.8268 - val_f1_score: 0.8817 - val_precision: 0.8874 - val_recall: 0.8814
# Epoch 38/50
# 148/148 [==============================] - 41s 274ms/step - loss: 0.1139 - accuracy: 0.9626 - auc: 0.9957 - cohen_kappa: 0.9437 - f1_score: 0.9617 - precision: 0.9646 - recall: 0.9605 - val_loss: 0.2738 - val_accuracy: 0.9085 - val_auc: 0.9813 - val_cohen_kappa: 0.8621 - val_f1_score: 0.9044 - val_precision: 0.9113 - val_recall: 0.9051
# Epoch 39/50
# 148/148 [==============================] - 40s 270ms/step - loss: 0.1213 - accuracy: 0.9601 - auc: 0.9950 - cohen_kappa: 0.9398 - f1_score: 0.9590 - precision: 0.9617 - recall: 0.9592 - val_loss: 0.4906 - val_accuracy: 0.8780 - val_auc: 0.9633 - val_cohen_kappa: 0.8156 - val_f1_score: 0.8697 - val_precision: 0.8801 - val_recall: 0.8712
# Epoch 40/50
# 148/148 [==============================] - 41s 274ms/step - loss: 0.1172 - accuracy: 0.9609 - auc: 0.9955 - cohen_kappa: 0.9411 - f1_score: 0.9599 - precision: 0.9625 - recall: 0.9601 - val_loss: 0.4374 - val_accuracy: 0.8746 - val_auc: 0.9628 - val_cohen_kappa: 0.8104 - val_f1_score: 0.8642 - val_precision: 0.8776 - val_recall: 0.8746
# Epoch 41/50
# 148/148 [==============================] - 41s 275ms/step - loss: 0.1161 - accuracy: 0.9596 - auc: 0.9957 - cohen_kappa: 0.9392 - f1_score: 0.9587 - precision: 0.9625 - recall: 0.9592 - val_loss: 0.3468 - val_accuracy: 0.9017 - val_auc: 0.9769 - val_cohen_kappa: 0.8516 - val_f1_score: 0.8966 - val_precision: 0.9017 - val_recall: 0.9017
# Epoch 42/50
# 148/148 [==============================] - 41s 278ms/step - loss: 0.1048 - accuracy: 0.9613 - auc: 0.9964 - cohen_kappa: 0.9418 - f1_score: 0.9602 - precision: 0.9638 - recall: 0.9605 - val_loss: 0.5082 - val_accuracy: 0.8610 - val_auc: 0.9580 - val_cohen_kappa: 0.7910 - val_f1_score: 0.8492 - val_precision: 0.8639 - val_recall: 0.8610
# Epoch 43/50
# 148/148 [==============================] - 41s 275ms/step - loss: 0.1127 - accuracy: 0.9660 - auc: 0.9953 - cohen_kappa: 0.9488 - f1_score: 0.9654 - precision: 0.9668 - recall: 0.9639 - val_loss: 0.3415 - val_accuracy: 0.8949 - val_auc: 0.9739 - val_cohen_kappa: 0.8420 - val_f1_score: 0.8907 - val_precision: 0.9010 - val_recall: 0.8949
# Epoch 44/50
# 148/148 [==============================] - 41s 276ms/step - loss: 0.1085 - accuracy: 0.9652 - auc: 0.9953 - cohen_kappa: 0.9475 - f1_score: 0.9642 - precision: 0.9659 - recall: 0.9626 - val_loss: 0.3925 - val_accuracy: 0.8746 - val_auc: 0.9663 - val_cohen_kappa: 0.8108 - val_f1_score: 0.8647 - val_precision: 0.8746 - val_recall: 0.8746
# Epoch 45/50
# 148/148 [==============================] - 42s 279ms/step - loss: 0.0961 - accuracy: 0.9677 - auc: 0.9965 - cohen_kappa: 0.9513 - f1_score: 0.9668 - precision: 0.9714 - recall: 0.9660 - val_loss: 0.2820 - val_accuracy: 0.8983 - val_auc: 0.9829 - val_cohen_kappa: 0.8469 - val_f1_score: 0.8937 - val_precision: 0.9010 - val_recall: 0.8949
# Epoch 46/50
# 148/148 [==============================] - 40s 270ms/step - loss: 0.1007 - accuracy: 0.9690 - auc: 0.9957 - cohen_kappa: 0.9533 - f1_score: 0.9680 - precision: 0.9714 - recall: 0.9664 - val_loss: 0.2515 - val_accuracy: 0.9085 - val_auc: 0.9843 - val_cohen_kappa: 0.8621 - val_f1_score: 0.9047 - val_precision: 0.9210 - val_recall: 0.9085
# Epoch 47/50
# 148/148 [==============================] - 42s 282ms/step - loss: 0.0762 - accuracy: 0.9724 - auc: 0.9981 - cohen_kappa: 0.9584 - f1_score: 0.9712 - precision: 0.9765 - recall: 0.9707 - val_loss: 0.2430 - val_accuracy: 0.9288 - val_auc: 0.9819 - val_cohen_kappa: 0.8928 - val_f1_score: 0.9273 - val_precision: 0.9286 - val_recall: 0.9254
# Epoch 48/50
# 148/148 [==============================] - 41s 277ms/step - loss: 0.1196 - accuracy: 0.9626 - auc: 0.9947 - cohen_kappa: 0.9437 - f1_score: 0.9617 - precision: 0.9646 - recall: 0.9601 - val_loss: 0.3446 - val_accuracy: 0.8915 - val_auc: 0.9747 - val_cohen_kappa: 0.8367 - val_f1_score: 0.8861 - val_precision: 0.8942 - val_recall: 0.8881
# Epoch 49/50
# 148/148 [==============================] - 42s 280ms/step - loss: 0.0897 - accuracy: 0.9681 - auc: 0.9969 - cohen_kappa: 0.9520 - f1_score: 0.9673 - precision: 0.9697 - recall: 0.9669 - val_loss: 0.2041 - val_accuracy: 0.9254 - val_auc: 0.9888 - val_cohen_kappa: 0.8877 - val_f1_score: 0.9234 - val_precision: 0.9349 - val_recall: 0.9254
# Epoch 50/50
# 148/148 [==============================] - 43s 289ms/step - loss: 0.0798 - accuracy: 0.9737 - auc: 0.9974 - cohen_kappa: 0.9603 - f1_score: 0.9731 - precision: 0.9761 - recall: 0.9724 - val_loss: 0.2731 - val_accuracy: 0.9153 - val_auc: 0.9793 - val_cohen_kappa: 0.8722 - val_f1_score: 0.9115 - val_precision: 0.9181 - val_recall: 0.9119

# %%
evaluate_model(model, history, test_generator)
# Out:
# Test set accuracy: 0.9658703207969666
#
# 19/19 [==============================] - 2s 126ms/step
#
#                      precision    recall  f1-score   support
#
#  Wheat___Brown_Rust       0.92      1.00      0.96        90
#     Wheat___Healthy       0.98      1.00      0.99       111
# Wheat___Yellow_Rust       1.00      0.89      0.94        92
#
#            accuracy                           0.97       293
#           macro avg       0.97      0.96      0.96       293
#        weighted avg       0.97      0.97      0.97       293
# ROC AUC score: 0.9983680393870822

# %%
import pandas as pd

# %%
from tensorflow.keras.utils import load_img, img_to_array
image_path= df_test['image_path'][85]
img = load_img(image_path, target_size=(224,224,3)) # stores image in PIL format
image_array=img_to_array(img)

# %%
from PIL import Image
display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=195x174 at 0x202D1F8A0C8>

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions

    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.layers[-2].output])

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Make model
model = model
last_conv_layer_name ="conv2d_8"
# Remove last layer's softmax
model.layers[-1].activation = None

img_array=np.expand_dims(image_array, axis=0)
# Prepare particular image 

# Generate class activation heatmap
heatmap= make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
import matplotlib.cm as cm
def save_and_display_gradcam(img_path, heatmap, cam_path, alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image.open(cam_path))

# %%
save_and_display_gradcam(image_path, heatmap,cam_path="Gradcam/GradCamPotato.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=195x174 at 0x202D1F7A888>
